# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Noor-Fatima313/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# # 1) My lane: Refresh / Content Opportunity Scoring
#
# I selected the Refresh / Content Opportunity Scoring lane.
#
# The goal of this lane is to identify which pages should be reviewed first for possible improvement.
#
# The dataset contains observable search and content performance signals such as impressions, clicks, CTR, sessions, and content-related metrics.
#
# This lane is useful because content teams have limited time and need a way to prioritize pages instead of manually reviewing every page.
#
# Data and ML can help identify patterns and rank pages based on evidence, while keeping human review as part of the final decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# # 2) Research Question
#
# ## Search Question
#
# Which pages should be prioritized for content refresh based on their search performance signals?
#
# ## Unit of Analysis
#
# The unit of analysis is a webpage/content item.
#
# Each row represents one content item and its observed performance information.
#
# ## Decision
#
# The decision is which pages the content team should review first for possible optimization.
#
# ## Action
#
# A reviewer could:
#
# - Update outdated content
# - Improve page structure
# - Improve titles or descriptions
# - Expand useful information
# - Monitor pages that do not require immediate changes
#
# ## Cost of a Wrong Recommendation
#
# A wrong recommendation could waste content team resources by focusing on pages with low improvement potential.
#
# It could also cause important opportunities to be missed if high-potential pages are ignored.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# ## 3) Quick Look at the Data
#
# I loaded the starter dataset and examined the available content performance signals.
#
# The dataset contains **30,000 content items and 44 columns**.
#
# Some important observations:
#
# - The average page received approximately **5,200 impressions in the last 90 days**.
# - The average number of sessions per page was approximately **37 sessions in the last 90 days**.
# - The average content age was approximately **256 days**.
#
# These numbers show that content pages have different levels of visibility, engagement, and maturity. This makes Refresh / Content Opportunity Scoring a useful direction because data can help identify which pages may deserve review and improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

# Dataset size
print("Dataset shape:", df.shape)

# Show important columns
print("\nColumns:")
print(df.columns.tolist())

# Show key statistics
print("\nAverage impressions:", df["impressions_90d"].mean())
print("Average sessions:", df["sessions_90d"].mean())
print("Average content age (days):", df["content_age_days"].mean())
# Out:
# Dataset shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# Average impressions: 5200.3663
# Average sessions: 37.066633333333336
# Average content age (days): 256.1678

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# ## 4) Careful Words: What I Can and Can't Claim
#
# ### What I can claim:
#
# - This project can identify **observed patterns** between content performance signals such as impressions, sessions, CTR, and content age.
# - The results can provide **directional insights** about which pages may deserve further review.
# - The output can work as **decision-support** for content teams when prioritizing pages for refresh or improvement.
#
# ### What I cannot claim:
#
# - I cannot prove that refreshing a page will directly cause an increase in traffic or engagement.
# - I cannot claim that the system can predict Google's ranking algorithm.
# - I cannot guarantee that every recommended page will improve after optimization.
# - The model will not replace human judgment; it will only support better decisions using available data.
#
# The purpose of this project is to help teams make informed decisions based on evidence, not to provide guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
